# %% [markdown]
# <a href="https://colab.research.google.com/github/KiNGxGoKu007/KiNGxGoKu007/blob/main/Forbes_Billionaires.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="/content/drive/MyDrive/DataSetsAnalysis/Forbes_Billionaire.csv"
forbes_df=pd.read_csv(path)
forbes_df.head()
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %%
forbes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2095 entries, 0 to 2094
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        2095 non-null   int64
#  1   Name        2095 non-null   object
#  2   Age         2052 non-null   float64
#  3   Net Worth   2095 non-null   float64
#  4   Country     2095 non-null   object
#  5   Source      2095 non-null   object
#  6   Industries  2095 non-null   object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 114.7+ KB

# %%
df1 = pd.read_csv('/content/drive/MyDrive/DataSetsAnalysis/Forbes_Billionaire.csv')
print('Rows',df1.shape,'Columns')
df1.head(5)
# Out:
# Rows (2095, 7) Columns
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %%
df2 = df1.groupby('Industries')['Age'].count().sort_values(ascending=False)
#df2.head(10)
df2.head(5)
df2.iloc[0:5].index.to_list()
#Finding out the top industries having the maximum number of Billionaires.
# OR
#df1['Industries'].value_counts().index.to_list()[0:8]
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate']

# %%
ind_list_asc = df1['Industries'].value_counts().reset_index().head(10)['Industries'].to_list()
ind_list_asc
# Out:
# ['Finance & Investments',
#  'Technology',
#  'Fashion & Retail',
#  'Manufacturing',
#  'Real Estate',
#  'Diversified',
#  'Food & Beverage',
#  'Healthcare',
#  'Energy',
#  'Media & Entertainment']

# %%
df1['Industries'].value_counts().reset_index().head(10)['count'].to_list()
# Out:
# [298, 241, 209, 198, 196, 169, 168, 149, 80, 74]

# %%
df33 = df1[df1['Industries'].isin(ind_list_asc[0:8])]
df3 = df33.groupby('Industries')['Net Worth'].mean().reset_index()
df3.head(10)
# Out:
#               Industries  Net Worth
# 0            Diversified   3.293491
# 1       Fashion & Retail   5.372727
# 2  Finance & Investments   3.430201
# 3        Food & Beverage   3.708333
# 4             Healthcare   2.857047
# 5          Manufacturing   2.730303
# 6            Real Estate   3.277551
# 7             Technology   5.634440

# %%
df4 = df1[df1['Industries'].isin(ind_list_asc[0:8])].groupby('Industries')['Age'].mean().reset_index()
df4.head(10)
# Out:
#               Industries        Age
# 0            Diversified  66.889571
# 1       Fashion & Retail  66.893204
# 2  Finance & Investments  65.810811
# 3        Food & Beverage  64.862500
# 4             Healthcare  63.088435
# 5          Manufacturing  64.139896
# 6            Real Estate  65.895288
# 7             Technology  55.375527

# %%
df1[df1['Industries']=='Automotive'].sort_values(by='Net Worth', ascending=False).head(1)
df1.head(5)
# Out:
#    Rank                      Name   Age  Net Worth        Country  \
# 0     1                JEFF BEZOS  56.0      113.0  United States
# 1     2                BILL GATES  64.0       98.0  United States
# 2     3  BERNARD ARNAULT & FAMILY  71.0       76.0         France
# 3     4            WARREN BUFFETT  89.0       67.5  United States
# 4     5             LARRY ELLISON  75.0       59.0  United States
#
#                Source             Industries
# 0              Amazon             Technology
# 1           Microsoft             Technology
# 2                LVMH       Fashion & Retail
# 3  Berkshire Hathaway  Finance & Investments
# 4            software             Technology

# %%
df6 = df1['Country'].value_counts().reset_index()
df6.head(5)
# Out:
#          Country  count
# 0  United States    614
# 1          China    387
# 2        Germany    107
# 3          India    102
# 4         Russia     99

# %%
l1 = df1.groupby('Country')['Industries'].count().sort_values(ascending=False).head(5).index.to_list()
l1
# Out:
# ['United States', 'China', 'Germany', 'India', 'Russia']

# %%
list1 = df1['Country'].value_counts().index.to_list()
list_main = list1[0:5]
list_main
# Out:
# ['United States', 'China', 'Germany', 'India', 'Russia']

# %%
df1[df1['Country'].isin(list_main)].groupby('Country')['Age'].mean().sort_values(ascending=True)
# Out:
# Country
# China            56.790026
# Russia           56.848485
# Germany          64.147368
# India            66.206186
# United States    66.911620
# Name: Age, dtype: float64

# %%
forbes_df.value_counts('Country')
# Out:
# Country
# United States           614
# China                   387
# Germany                 107
# India                   102
# Russia                   99
#                        ...
# Guernsey                  1
# Georgia                   1
# Eswatini (Swaziland)      1
# Belgium                   1
# Zimbabwe                  1
# Name: count, Length: 72, dtype: int64

# %%
df1[df1['Country']=='China'].sort_values(by='Net Worth', ascending=False).head(1)['Name']
# .head(1)
# Out:
# 16    JACK MA
# Name: Name, dtype: object

# %%
df1[df1['Country']=='India'].groupby('Industries')['Source'].count().sort_values(ascending=False)
#  ['Industries'].value_counts().head(5).index.to_list()
# Out:
# Industries
# Healthcare                    17
# Manufacturing                 14
# Diversified                   13
# Technology                    11
# Food & Beverage                8
# Real Estate                    8
# Automotive                     6
# Fashion & Retail               6
# Construction & Engineering     4
# Finance & Investments          4
# Service                        4
# Metals & Mining                3
# Energy                         2
# Media & Entertainment          1
# Telecom                        1
# Name: Source, dtype: int64

# %%
df1[df1['Country']=='India']['Industries'].value_counts().head(5)
# Out:
# Industries
# Healthcare         17
# Manufacturing      14
# Diversified        13
# Technology         11
# Food & Beverage     8
# Name: count, dtype: int64

# %%
df10 = df1.sort_values(by='Net Worth', ascending=False).reset_index(drop=True).iloc[0:100, :]
df10[df10['Country']=='India'].head(10)
# Out:
#     Rank                         Name   Age  Net Worth Country  \
# 20    21                MUKESH AMBANI  62.0       36.8   India
# 77    78  RADHAKISHAN DAMANI & FAMILY  65.0       13.8   India
#
#                        Source        Industries
# 20  petrochemicals, oil & gas            Energy
# 77        retail, investments  Fashion & Retail

# %%
df12 = df1[(df1['Country']=='India') & (df1['Age']<50)]
df12.head(10)
# Out:
#       Rank                  Name   Age  Net Worth Country  \
# 874    875  VIJAY SHEKHAR SHARMA  41.0        2.4   India
# 1196  1196       BYJU RAVEENDRAN  38.0        1.8   India
# 1237  1196          VIKAS OBEROI  49.0        1.8   India
# 1420  1415            RANJAN PAI  47.0        1.5   India
# 1618  1613     SHAMSHEER VAYALIL  43.0        1.3   India
# 1732  1730         SACHIN BANSAL  38.0        1.2   India
# 1742  1730           RADHA VEMBU  47.0        1.2   India
# 1856  1851          BINNY BANSAL  37.0        1.1   India
# 1867  1851    ACHARYA BALKRISHNA  47.0        1.1   India
#
#                     Source        Industries
# 874   financial technology           Service
# 1196  education technology        Technology
# 1237           real estate       Real Estate
# 1420             education           Service
# 1618            healthcare        Healthcare
# 1732              flipkart  Fashion & Retail
# 1742            technology        Technology
# ...

# %%
dtrump_worth = df1[df1['Name']=='DONALD TRUMP']['Net Worth'].reset_index(drop=True)[0]
dtrump_worth
# Out:
# 2.1

# %%
df1[(df1['Country']=='India') & (df1['Industries']=='Real Estate') & (df1['Net Worth']>dtrump_worth)]
# Out:
#      Rank              Name   Age  Net Worth Country       Source   Industries
# 494   494  KUSHAL PAL SINGH  88.0        3.7   India  real estate  Real Estate
# 774   764    CHANDRU RAHEJA  79.0        2.7   India  real estate  Real Estate

# %%
df1['Net Worth'].sum()
# Out:
# 8037.499999999999
